# %% [markdown]
# # SQL CARTO QUERY FUNCTION
# # written for PUI2016_Python2

# %% [markdown]
# ##### This notebook is set up to link as a default to the fb55 account.  To turn in the homework use the same account you used in the lab (hvt201)  and query the database that you were querying in class (citibike_feb_2015)

# %%
#python2
#SQL_SOURCE = 'https://fb55.carto.com/api/v2/sql?q='

#import urllib2
#import urllib
#import StringIO
#import ast
#import pandas as pd

#def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    #'''queries carto datasets from a given carto account
    #Arguments: 
    #query - string: a valid sql query string
    #format - outlut format  OPTIONAL (default CSV)
    #source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    #Returns:
    #the return of the sql query AS A STRING
    #NOTES:
    #designed for the carto API, tested only with CSV return format'''
    
    #data = urllib.urlencode({'format': format, 'q': query})
    #try:
        #response = urllib2.urlopen(source, data)
    #except (urllib2.HTTPError, e):
        #raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    #except Exception:
        #raise
    #return response.read()

#python2,3 compatible
try:
    import urllib2 as ulib
except ImportError:
    import urllib as ulib

try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io

try:
    from urllib import urlencode as urlencode
except ImportError:
    from urllib.parse import urlencode as urlencode
    
try:
    from urllib import urlopen as urlopen
except ImportError:
    from urllib.request import urlopen as urlopen
    
try:
    from urllib2 import HTTPError as HTTPError
except ImportError:
    from urllib.error import HTTPError as HTTPError

import ast
import pandas as pd

API_URL = 'https://fb55.carto.com:443/api/v2/sql?q='

def queryCartoDB(query, formatting = 'CSV', source = API_URL):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    
    data = urlencode({'format': formatting, 'q': query}).encode("utf-8")
    try:
        response = urlopen(source, data)
        return response.read()
    except HTTPError as e:
        raise (ValueError('\n'.join(ast.literal_eval(e.readline())['error'])))
        
def get_data(query):
    try:
        return pd.read_csv(io(queryCartoDB(query)), sep = ',')
    except ValueError as v:
        print (str(v))

# %% [markdown]
# ## Task 1.1 Sort data by start_station_id, tripduration
# ### Only checking trips with duration <= 3 hours

# %%
query = '''
SELECT start_station_id, tripduration
FROM htv210.citibike_feb_2015
WHERE tripduration <= 10800
ORDER BY start_station_id
'''
table = get_data(query)
table
# Out:
#        start_station_id  tripduration
# 0                    72           396
# 1                    72           517
# 2                    72           420
# 3                    72          1242
# 4                    72           569
# 5                    72           301
# 6                    72          1382
# 7                    72           479
# 8                    72           915
# 9                    72           621
# 10                   72           348
# 11                   72           777
# 12                   72           377
# 13                   72           613
# 14                   72          1678
# 15                   72           386
# 16                   72           288
# 17                   72           424
# 18                   72          1388
# 19                   72           432
# 20                   72          1914
# 21                   72           429
# 22                   72           728
# 23                   72           668
# ...

# %% [markdown]
# ## Task 1.2 Only show the top/last 10 records (aka head and tail in SQL)

# %%
#TOP 10
query = '''
SELECT * FROM htv210.citibike_feb_2015
ORDER BY cartodb_id ASC
LIMIT 10;
'''
table = get_data(query)
table.head(10)
# Out:
#    the_geom  start_station_longitude  the_geom_webmercator  tripduration  \
# 0       NaN               -73.994811                   NaN           801
# 1       NaN               -73.990093                   NaN           379
# 2       NaN               -73.973715                   NaN          2474
# 3       NaN               -74.004704                   NaN           818
# 4       NaN               -73.986317                   NaN           544
# 5       NaN               -73.953820                   NaN           717
# 6       NaN               -73.977225                   NaN          1306
# 7       NaN               -73.989780                   NaN           913
# 8       NaN               -73.994046                   NaN           759
# 9       NaN               -74.002638                   NaN           585
#
#                 starttime                stoptime  start_station_id  \
# 0  2015-02-01 00:00:00+00  2015-02-01 00:14:00+00               521
# ...

# %%
#LAST 10
query = '''
SELECT * FROM htv210.citibike_feb_2015
ORDER BY cartodb_id DESC
LIMIT 10;
'''
table = get_data(query)
table.head(10)
# Out:
#    the_geom  start_station_longitude  the_geom_webmercator  tripduration  \
# 0       NaN               -73.989780                   NaN           917
# 1       NaN               -74.002150                   NaN           548
# 2       NaN               -73.986831                   NaN           392
# 3       NaN               -73.986831                   NaN           428
# 4       NaN               -74.000040                   NaN           689
# 5       NaN               -73.969053                   NaN          1422
# 6       NaN               -73.982050                   NaN           993
# 7       NaN               -74.009106                   NaN          1165
# 8       NaN               -73.993012                   NaN          1248
# 9       NaN               -74.001497                   NaN           306
#
#                 starttime                stoptime  start_station_id  \
# 0  2015-02-07 23:59:00+00  2015-02-08 00:15:00+00               439
# ...

# %% [markdown]
# ## Task 1.3 List all unique start_station_id values

# %%
query = '''
SELECT DISTINCT start_station_id FROM htv210.citibike_feb_2015
WHERE start_station_id IS NOT NULL;
'''
table = get_data(query)
table
# Out:
#      start_station_id  Unnamed: 1
# 0                 120         NaN
# 1                 285         NaN
# 2                 251         NaN
# 3                 195         NaN
# 4                 453         NaN
# 5                 144         NaN
# 6                 266         NaN
# 7                 263         NaN
# 8                 216         NaN
# 9                 328         NaN
# 10                353         NaN
# 11                212         NaN
# 12                383         NaN
# 13                538         NaN
# 14                217         NaN
# 15                300         NaN
# 16                456         NaN
# 17                128         NaN
# 18                223         NaN
# 19                244         NaN
# 20                494         NaN
# 21                403         NaN
# 22                260         NaN
# 23                411         NaN
# 24                445         NaN
# 25                377         NaN
# ...

# %% [markdown]
# ## Task 1.4 Aggregation functions:
# - Count the number of trips (aka wc -l in SQL)
# - Find the average/min/max trip duration

# %%
query = '''
SELECT COUNT(cartodb_id)
FROM htv210.citibike_feb_2015
'''
table = get_data(query)
table.head()
# Out:
#    count  Unnamed: 1
# 0  46200         NaN

# %%
query = '''
SELECT MIN(tripduration) FROM htv210.citibike_feb_2015;
'''
table = get_data(query)
table.head()
# Out:
#    min  Unnamed: 1
# 0   60         NaN

# %%
query = '''
SELECT MAX(tripduration) FROM htv210.citibike_feb_2015;
'''
table = get_data(query)
table.head()
# Out:
#      max  Unnamed: 1
# 0  43016         NaN

# %%
query = '''
SELECT AVG(tripduration) FROM htv210.citibike_feb_2015;
'''
table = get_data(query)
table.head()
# Out:
#           avg  Unnamed: 1
# 0  675.865823         NaN

# %% [markdown]
# ## Task 2.1 Selecting trips started on Feb-02-2015 only

# %%
query = '''
SELECT *
FROM htv210.citibike_feb_2015
WHERE starttime BETWEEN '2/2/2015 00:00:00.00' AND '2/2/2015 23:59:59.999'
'''
table = get_data(query)
table
# Out:
#       the_geom  start_station_longitude  the_geom_webmercator  tripduration  \
# 0          NaN               -73.979955                   NaN          1312
# 1          NaN               -74.004432                   NaN           444
# 2          NaN               -74.004432                   NaN           438
# 3          NaN               -73.990931                   NaN           498
# 4          NaN               -73.993915                   NaN           199
# 5          NaN               -73.984267                   NaN           418
# 6          NaN               -74.001670                   NaN           276
# 7          NaN               -73.992390                   NaN           420
# 8          NaN               -73.990026                   NaN           304
# 9          NaN               -73.978951                   NaN           622
# 10         NaN               -74.003664                   NaN           371
# ...

# %% [markdown]
# ## Task 2.2 Selecting trips started on the weekends
# - What are avaerge trip duration during weekends?

# %%
#2/1,2/7
query = '''
SELECT starttime, tripduration
FROM htv210.citibike_feb_2015
WHERE EXTRACT(DAY FROM starttime::date)=1 or EXTRACT(DAY FROM starttime::date)=7;
'''
table = get_data(query)
table
# Out:
#                     starttime  tripduration
# 0      2015-02-01 01:11:00+00           447
# 1      2015-02-01 10:26:00+00           277
# 2      2015-02-01 11:07:00+00           526
# 3      2015-02-01 12:37:00+00           502
# 4      2015-02-01 12:46:00+00           943
# 5      2015-02-01 12:54:00+00           563
# 6      2015-02-01 15:21:00+00           519
# 7      2015-02-01 17:38:00+00           500
# 8      2015-02-01 17:48:00+00           374
# 9      2015-02-01 19:26:00+00           420
# 10     2015-02-01 21:34:00+00           315
# 11     2015-02-07 06:33:00+00           302
# 12     2015-02-07 00:00:00+00           424
# 13     2015-02-07 03:43:00+00           439
# 14     2015-02-07 09:16:00+00           463
# 15     2015-02-07 09:32:00+00           852
# 16     2015-02-07 10:35:00+00          2049
# 17     2015-02-07 11:31:00+00           400
# 18     2015-02-07 11:57:00+00          1597
# 19     2015-02-07 12:37:00+00           996
# ...

# %%
query = '''
SELECT AVG(tripduration) as weekend_avg
FROM htv210.citibike_feb_2015
WHERE EXTRACT(DAY FROM starttime::date)=1 or EXTRACT(DAY FROM starttime::date)=7;
'''
table = get_data(query)
table.head()
# Out:
#    weekend_avg  Unnamed: 1
# 0   662.942181         NaN

# %% [markdown]
# ## Task 2.3 Can we do the same for weekday?

# %%
query = '''
SELECT starttime , tripduration
FROM htv210.citibike_feb_2015
WHERE EXTRACT(DAY FROM starttime::date)= 2 or EXTRACT(DAY FROM starttime::date)= 3 or EXTRACT(DAY FROM starttime::date)= 4 or EXTRACT(DAY FROM starttime::date)= 5 or EXTRACT(DAY FROM starttime::date)= 6;
'''
table = get_data(query)
table
# Out:
#                     starttime  tripduration
# 0      2015-02-02 11:07:00+00          1312
# 1      2015-02-03 10:33:00+00           360
# 2      2015-02-03 12:51:00+00           617
# 3      2015-02-03 16:55:00+00           233
# 4      2015-02-03 17:27:00+00           768
# 5      2015-02-03 17:44:00+00           392
# 6      2015-02-03 18:01:00+00           647
# 7      2015-02-03 19:55:00+00          3589
# 8      2015-02-03 19:55:00+00           319
# 9      2015-02-04 07:58:00+00           538
# 10     2015-02-04 08:15:00+00           883
# 11     2015-02-04 08:37:00+00           583
# 12     2015-02-04 08:46:00+00           966
# 13     2015-02-04 09:13:00+00           496
# 14     2015-02-04 11:58:00+00           353
# 15     2015-02-04 17:56:00+00           707
# 16     2015-02-04 19:12:00+00           351
# 17     2015-02-04 22:27:00+00           191
# 18     2015-02-05 05:42:00+00           159
# 19     2015-02-05 08:36:00+00           822
# ...

# %%
query = '''
SELECT AVG(tripduration) as weekend_avg
FROM htv210.citibike_feb_2015
WHERE EXTRACT(DAY FROM starttime::date)= 2 or EXTRACT(DAY FROM starttime::date)= 3 or EXTRACT(DAY FROM starttime::date)= 4 or EXTRACT(DAY FROM starttime::date)= 5 or EXTRACT(DAY FROM starttime::date)= 6;
'''
table = get_data(query)
table.head()
# Out:
#    weekend_avg  Unnamed: 1
# 0   681.052292         NaN

# %% [markdown]
# ## Task 3.1 Showing the list of start station locations
# - Using GROUP BY

# %%
query = '''
SELECT DISTINCT start_station_name FROM htv210.citibike_feb_2015
WHERE start_station_name IS NOT NULL
GROUP BY start_station_name;
'''
table = get_data(query)
table
# Out:
#                 start_station_name  Unnamed: 1
# 0                 10 Ave & W 28 St         NaN
# 1                 11 Ave & W 27 St         NaN
# 2                 11 Ave & W 41 St         NaN
# 3                 11 Ave & W 59 St         NaN
# 4                 12 Ave & W 40 St         NaN
# 5                  1 Ave & E 15 St         NaN
# 6                  1 Ave & E 44 St         NaN
# 7                  2 Ave & E 31 St         NaN
# 8                  2 Ave & E 58 St         NaN
# 9          3 Ave & Schermerhorn St         NaN
# 10                 5 Ave & E 29 St         NaN
# 11               6 Ave & Broome St         NaN
# 12                6 Ave & Canal St         NaN
# 13                 6 Ave & W 33 St         NaN
# 14                 8 Ave & W 31 St         NaN
# 15                 8 Ave & W 33 St         NaN
# 16                 8 Ave & W 52 St         NaN
# 17                 9 Ave & W 14 St         NaN
# 18                 9 Ave & W 16 St         NaN
# ...

# %% [markdown]
# ## Task 3.2 Showing the number of trips started per station

# %%
query = '''
SELECT start_station_name,
COUNT(cartodb_id) as trips 
FROM htv210.citibike_feb_2015
GROUP BY start_station_name;
'''
table = get_data(query)
table
# Out:
#                 start_station_name  trips
# 0             E 30 St & Park Ave S    227
# 1          Pearl St & Anchorage Pl     54
# 2                  W 56 St & 6 Ave    164
# 3                   West Thames St    107
# 4          Bank St & Washington St    125
# 5                  8 Ave & W 52 St    133
# 6               E 11 St & Broadway    115
# 7         DeKalb Ave & Skillman St     10
# 8    Atlantic Ave & Fort Greene Pl     36
# 9                Avenue D & E 8 St     38
# 10            S 3 St & Bedford Ave     13
# 11          W Broadway & Spring St    159
# 12                 2 Ave & E 31 St    302
# 13                 E 33 St & 5 Ave    213
# 14        MacDougal St & Prince St    247
# 15    Clermont Ave & Lafayette Ave     25
# 16          Barclay St & Church St    244
# 17          Forsyth St & Broome St    212
# 18                 W 13 St & 6 Ave    257
# 19              E 20 St & Park Ave    218
# 20                 W 17 St & 8 Ave    288
# ...

# %% [markdown]
# ## Task 3.3 ...but only for stations within 500m of Time Square!
# - The coordinates of Time Square is (40.7577, -73.9857)

# %%
query = '''
SELECT start_station_name, COUNT(cartodb_id) as trips,
(SQRT(POW(start_station_latitude -40.7577,2) + POW(start_station_longitude +73.9857,2))*111000) as distance
FROM htv210.citibike_feb_2015
WHERE (SQRT(POWER(start_station_latitude -40.7577,2) + POWER(start_station_longitude +73.9857,2))*111000) < 500
GROUP BY start_station_name, start_station_latitude, start_station_longitude
ORDER BY distance
'''
table = get_data(query)
table
# Out:
#    start_station_name  trips    distance
# 0  Broadway & W 41 St    251  300.956692
# 1     W 45 St & 6 Ave    141  325.239186
# 2  Broadway & W 49 St    213  356.328056
# 3     W 45 St & 8 Ave    141  366.834679
# 4     W 43 St & 6 Ave    112  389.199116

# %% [markdown]
# ## Task 4.1 Find the station that had the longest average trip duration during weekends and within 500m of TimeSquare!

# %%
query = '''
SELECT start_station_name, AVG(tripduration)
FROM htv210.citibike_feb_2015
WHERE SQRT(POW(start_station_latitude - 40.7577 , 2) + POW(start_station_longitude +73.9857, 2)) * 111000 < 500 AND EXTRACT(DAY FROM starttime::date) = 1 or EXTRACT(DAY FROM starttime::date) = 7
GROUP BY start_station_name
ORDER BY AVG(tripduration) DESC
LIMIT 1
'''
table = get_data(query)
table.head()
# Out:
#   start_station_name          avg
# 0    W 33 St & 7 Ave  2199.037037

# %% [markdown]
# ## Task 4.2 Extra: create lines for trips started from stations within 500m of Time Squares and lasted less than 2 hours. The number of trips per each pair of station are output as attributes of these lines.

# %%
query = '''
SELECT start_station_name, end_station_name,COUNT(tripduration)
FROM htv210.citibike_feb_2015
WHERE SQRT(POW(start_station_latitude - 40.7577 , 2) + POW(start_station_longitude +73.9857, 2)) * 111000 < 500 and tripduration <= 7200
GROUP BY start_station_name, end_station_name
ORDER BY COUNT(tripduration)
'''
table = get_data(query)
table
# Out:
#      start_station_name            end_station_name  count
# 0       W 45 St & 6 Ave     E 53 St & Lexington Ave      1
# 1       W 45 St & 6 Ave             E 25 St & 1 Ave      1
# 2    Broadway & W 41 St             E 10 St & 5 Ave      1
# 3       W 43 St & 6 Ave             E 39 St & 3 Ave      1
# 4       W 45 St & 8 Ave        E 30 St & Park Ave S      1
# 5    Broadway & W 49 St          Broadway & W 29 St      1
# 6       W 45 St & 6 Ave          Broadway & W 55 St      1
# 7    Broadway & W 41 St        Allen St & Hester St      1
# 8       W 45 St & 6 Ave             E 25 St & 2 Ave      1
# 9       W 45 St & 8 Ave             9 Ave & W 45 St      1
# 10      W 43 St & 6 Ave         FDR Drive & E 35 St      1
# 11   Broadway & W 41 St             9 Ave & W 45 St      1
# 12   Broadway & W 41 St           E 7 St & Avenue A      1
# 13   Broadway & W 49 St            W 56 St & 10 Ave      1
# 14   Broadway & W 41 St     Duane St & Greenwich St      1
# ...

# %% [markdown]
# # Extra credit: make the function python 2 and 3 compatible so that it works on the  PUI2016_Python3 kernel
